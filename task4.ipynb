# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('DataSet_task_4.csv')
df.head()
# Out:
#           x           y
# 0  1.045296  521.384929
# 1  1.881533  482.281059
# 2  2.090592  456.211813
# 3  3.031359  488.798371
# 4  3.344948  602.851324

# %%
X2 = df[['x']]
y2 = df['y']
X2
# Out:
#             x
# 0    1.045296
# 1    1.881533
# 2    2.090592
# 3    3.031359
# 4    3.344948
# ..        ...
# 75  25.139373
# 76  25.923345
# 77  26.759582
# 78  27.334495
# 79  29.059233
#
# [80 rows x 1 columns]

# %%
# X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=42)

# %%
poly = PolynomialFeatures(degree=10)
# X2_poly_train = poly.fit_transform(X2_train)
# X2_poly_test = poly.fit_transform(X2_test)
X2_poly = poly.fit_transform(X2)

# %%
model = LinearRegression()
model.fit(X2_poly, y2)
# Out:
# LinearRegression()

# %%
y2_pred = model.predict(X2_poly)
y2_pred
# Out:
# array([ 479.03443209,  520.5538738 ,  535.55379219,  623.16676692,
#         658.43188357,  535.55379219,  640.48688961,  676.94102168,
#         689.56358857,  851.9412046 ,  851.9412046 ,  928.09299772,
#         928.09299772,  982.12024552, 1008.41626992, 1095.24795606,
#        1040.43772807, 1059.13857157, 1151.1210949 , 1151.1210949 ,
#        1236.1151221 , 1270.45707683, 1270.45707683, 1290.24421935,
#        1273.92773925, 1317.73658179, 1320.11447506, 1315.29194669,
#        1364.78054936, 1364.78054936, 1364.03335871, 1364.03335871,
#        1359.07561005, 1361.71767342, 1354.54617147, 1348.77987898,
#        1339.53809678, 1359.4306916 , 1337.60201794, 1343.3387266 ,
#        1317.99549618, 1314.19912233, 1309.57230767, 1292.38597866,
#        1283.34044614, 1302.4651011 , 1294.85831866, 1291.56573431,
#        1277.3350236 , 1272.75587557, 1263.51078125, 1264.61854372,
#        1236.76384828, 1231.27542614, 1246.57822362, 1214.48636944,
# ...

# %%
plt.scatter(X2, y2, color='blue', label='Original Data') 
plt.plot(X2, y2_pred, color='red', label=f'Polynomial Fit (Degree {10})')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial Regression')
plt.legend()
plt.show()

# %%
mse_sklearn = mean_squared_error(y2, y2_pred)
print("Sklearn MSE:", mse_sklearn)
# Out:
# Sklearn MSE: 10949.471022617114

# %%
mse_results = []
degrees = range(1, 21)

for degree in degrees:
    poly = PolynomialFeatures(degree=degree)
    X2_poly = poly.fit_transform(X2)

    model = LinearRegression()
    model.fit(X2_poly, y2)

    y2_pred = model.predict(X2_poly)

    mse = mean_squared_error(y2, y2_pred)
    mse_results.append(mse)
    print(f"Degree {degree}: MSE = {mse}")

# # Plotting the degree vs. MSE
# plt.plot(degrees, mse_results, marker='o')
# plt.xlabel('Degree of Polynomial')
# plt.ylabel('Mean Squared Error (MSE)')
# plt.title('Polynomial Degree vs. MSE')
# plt.grid()
# plt.show()
# Out:
# Degree 1: MSE = 88014.94776709887
# Degree 2: MSE = 13401.016347243287
# Degree 3: MSE = 12329.381592745545
# Degree 4: MSE = 12292.833421185594
# Degree 5: MSE = 12156.821662555574
# Degree 6: MSE = 11331.569772330327
# Degree 7: MSE = 11218.438816495292
# Degree 8: MSE = 11009.092551798993
# Degree 9: MSE = 10991.500472396816
# Degree 10: MSE = 10949.471022617114
# Degree 11: MSE = 13331.441816689077
# Degree 12: MSE = 17602.99538807898
# Degree 13: MSE = 23247.66693778758
# Degree 14: MSE = 29064.86565387669
# Degree 15: MSE = 43060.437870313115
# Degree 16: MSE = 46404.69644912923
# Degree 17: MSE = 49174.59439735055
# Degree 18: MSE = 51468.113514026205
# Degree 19: MSE = 53355.277969953895
# Degree 20: MSE = 54898.43974967027
